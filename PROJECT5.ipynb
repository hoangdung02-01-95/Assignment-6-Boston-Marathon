# %% [markdown]
# # I. INTRODUCTION

# %% [markdown]
# In this notebook, My goal is creat a model to predicting flight delays at take-off. The purpose is not to obtain the best possible prediction but I want to show you step to step build sucesses a model. Along this path, I then put in some basic but important concepts. Among then, I comment on the importance of dataset how to use all model : Naïve Bayes, Logistic Regression, Decision Tree, Random Forest and SVM. I give some insight on the reason why regularization helps us in developing models that generalize well.

# %% [markdown]
# The data at : http://stat-computing.org/dataexpo/2009/the-data.html.

# %% [markdown]
# ## Description of the data

# %% [markdown]
# 	Name	Description
# * 1.Year        ----------1987-2008
# * 2.Month       ----------1-12
# * 3.DayofMonth ----------1-31
# * 4.DayOfWeek     ----------           1 (Monday) - 7 (Sunday)
# * 5.DepTime           ----------                              actual departure time (local, hhmm)
# * 6.CRSDepTime ----------                     scheduled departure time (local, hhmm)
# * 7.ArrTime      ----------                                   actual arrival time (local, hhmm)
# * 8.CRSArrTime      ----------                                   scheduled arrival time (local, hhmm)
# * 9.UniqueCarrier   ----------                                      unique carrier code
# * 10.FlightNum     ----------                                    flight number
# * 11.TailNum  ----------                                     plane tail number
# * 12.ActualElapsedTime  ----------                                       in minutes
# * 13.CRSElapsedTime      ----------                                   in minutes
# * 14.AirTime ----------                                        in minutes
# * 15.ArrDelay ----------                                        arrival delay, in minutes
# * 16.DepDelay ----------                                        departure delay, in minutes
# * 17.Origin ----------                                        origin IATA airport code
# * 18.Dest----------                                         destination IATA airport code
# * 19.Distance  ----------                                       in miles
# * 20.TaxiIn----------                                         taxi in time, in minutes
# * 21.TaxiOut ----------                                        taxi out time in minutes
# * 22.Cancelled  ----------                                       was the flight cancelled?
# * 23.CancellationCode     ----------                                    reason for cancellation (A = carrier, B = weather, C = NAS, D = security)
# * 24.Diverted    ----------                                     1 = yes, 0 = no
# * 25.CarrierDelay  ----------                                       in minutes
# * 26.WeatherDelay  ----------                                       in minutes
# * 27.NASDelay      ----------                                   in minutes
# * 28.SecurityDelay ----------                                        in minutes
# * 29.LateAircraftDelay  ----------                                       in minutes

# %% [markdown]
# Import all library we need in this project.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

import os
os.environ['PROJ_LIB'] = 'C:\\Users\\nhdhc\\AppData\\Local\\Continuum\\anaconda3\\Lib\\site-packages\\mpl_toolkits\\basemap'
from mpl_toolkits.basemap import Basemap
import plotly.offline as py
import plotly.figure_factory as ff
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
from plotly import tools
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # II. TRANSFORMS DATA

# %% [markdown]
# ## Load data

# %%
data_flight = pd.read_csv('2008.csv')

# %%
data_flight.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
data_flight.shape
# Out:
# (7009728, 29)

# %% [markdown]
# Data have 700924 samples and 29 features.

# %%
data_flight.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
data_flight.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
# Looking for NaN
display(data_flight.isnull().any())
# Out:
# Year                 False
# Month                False
# DayofMonth           False
# DayOfWeek            False
# DepTime               True
# CRSDepTime           False
# ArrTime               True
# CRSArrTime           False
# UniqueCarrier        False
# FlightNum            False
# TailNum               True
# ActualElapsedTime     True
# CRSElapsedTime        True
# AirTime               True
# ArrDelay              True
# DepDelay              True
# Origin               False
# Dest                 False
# Distance             False
# TaxiIn                True
# TaxiOut               True
# Cancelled            False
# CancellationCode      True
# Diverted             False
# CarrierDelay          True
# WeatherDelay          True
# NASDelay              True
# SecurityDelay         True
# LateAircraftDelay     True
# dtype: bool

# %%
data_flight.isnull().sum()/len(data_flight)*100
# Out:
# Year                  0.000000
# Month                 0.000000
# DayofMonth            0.000000
# DayOfWeek             0.000000
# DepTime               1.943670
# CRSDepTime            0.000000
# ArrTime               2.163408
# CRSArrTime            0.000000
# UniqueCarrier         0.000000
# FlightNum             0.000000
# TailNum               1.189276
# ActualElapsedTime     2.206919
# CRSElapsedTime        0.012040
# AirTime               2.206919
# ArrDelay              2.206919
# DepDelay              1.943670
# Origin                0.000000
# Dest                  0.000000
# Distance              0.000000
# TaxiIn                2.163408
# TaxiOut               1.955254
# Cancelled             0.000000
# CancellationCode     98.039382
# Diverted              0.000000
# CarrierDelay         78.248300
# WeatherDelay         78.248300
# NASDelay             78.248300
# SecurityDelay        78.248300
# LateAircraftDelay    78.248300
# dtype: float64

# %% [markdown]
# In dataset we has :
# * CancellationCode missing :  98.039382%
# * CarrierDelay     missing :  78.248300%
# * NASDelay    missing :  78.248300%
# * WeatherDelay     missing :  78.248300%
# * SecurityDelay    missing :  78.248300%
# * LateAircraftDelay    missing :  78.248300%
#
# => I decided remove features above.

# %%
data_flight=data_flight.drop(columns=['CancellationCode', 'CarrierDelay','NASDelay','WeatherDelay','SecurityDelay','LateAircraftDelay'])
data_flight.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... AirTime  ArrDelay  DepDelay  \
# 0        2225            WN        335  ...   116.0     -14.0       8.0
# 1        1000            WN       3231  ...   113.0       2.0      19.0
# 2         750            WN        448  ...    76.0      14.0       8.0
# 3        1100            WN       1746  ...    78.0      -6.0      -4.0
# 4        1925            WN       3920  ...    77.0      34.0      34.0
#
#    Origin  Dest  Distance TaxiIn TaxiOut  Cancelled  Diverted
# ...

# %%
data_flight.describe()
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  7009728.0  7.009728e+06  7.009728e+06  7.009728e+06  6.873482e+06
# mean      2008.0  6.375130e+00  1.572801e+01  3.924182e+00  1.333830e+03
# std          0.0  3.406737e+00  8.797068e+00  1.988259e+00  4.780689e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  9.280000e+02
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.325000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.728000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#          CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  7.009728e+06  6.858079e+06  7.009728e+06  7.009728e+06
# mean   1.326086e+03  1.481258e+03  1.494801e+03  2.224200e+03
# std    4.642509e+02  5.052251e+02  4.826728e+02  1.961716e+03
# ...

# %% [markdown]
# I see in the dataset and not see a mistake.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

fig, ax = plt.subplots(figsize=(12,15))
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
m.bluemarble()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
data_flight=data_flight.dropna()
data_flight.isnull().sum()
# Out:
# Year                 0
# Month                0
# DayofMonth           0
# DayOfWeek            0
# DepTime              0
# CRSDepTime           0
# ArrTime              0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# TailNum              0
# ActualElapsedTime    0
# CRSElapsedTime       0
# AirTime              0
# ArrDelay             0
# DepDelay             0
# Origin               0
# Dest                 0
# Distance             0
# TaxiIn               0
# TaxiOut              0
# Cancelled            0
# Diverted             0
# fly_speed            0
# dtype: int64

# %%
data_flight.shape
# Out:
# (6855024, 24)

# %%
attrition_count={}
for entry in data_flight["UniqueCarrier"]:
    if entry in attrition_count.keys():
        attrition_count[entry]+=1
    else:
        attrition_count[entry]=1


print(attrition_count)
# Out:
# {'WN': 1186911, 'XE': 363414, 'YV': 245131, 'OH': 190692, 'OO': 553412, 'UA': 437979, 'US': 446086, 'DL': 443934, 'EV': 274867, 'F9': 95384, 'FL': 258713, 'HA': 61212, 'MQ': 471161, 'NW': 344110, '9E': 254320, 'AA': 585485, 'AQ': 7752, 'AS': 148492, 'B6': 192114, 'CO': 293855}

# %%
data_flight_new=data_flight[data_flight['Distance']>0]
data_flight_new=data_flight[data_flight['AirTime']>0]
data_flight_new['fly_speed'] = data_flight_new['Distance']/data_flight_new['AirTime']
sns.set_context("notebook", font_scale=2.5)
sns.set(style="ticks", palette="muted", color_codes=True)
ax = sns.boxplot(x="fly_speed", y="UniqueCarrier", data=data_flight_new);
sns.despine(trim=True)

# %%
axis = plt.subplots(figsize=(10,14))
Name = data_flight["UniqueCarrier"].unique()
size = data_flight["UniqueCarrier"].value_counts()
plt.pie(size,labels=Name,autopct='%5.0f%%')
plt.show()

# %%
dff = df.MONTH.value_counts().to_frame().reset_index().sort_values(by='index')
dff.columns = ['month', 'flight_num']
month = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May',
            6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
dff.month = dff.month.map(month)

trace = go.Bar(
    x=dff.month,
    y=dff.flight_num,
    marker=dict(
        color = dff.flight_num,
        colorscale='Reds',
        showscale=True)
)

data = [trace]
layout = go.Layout(
    title='# of Flights (monthly)', 
    yaxis = dict(title = '# of Flights'
                                                )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)

# %%
# Plot to show the Taxi In and Taxi Out Time
axis = plt.subplots(figsize=(10,14))
sns.set_color_codes("pastel")
sns.set_context("notebook", font_scale=1.5)
axis = sns.barplot(x="TaxiOut", y="UniqueCarrier", data=data_flight, color="g")
axis = sns.barplot(x="TaxiIn", y="UniqueCarrier", data=data_flight, color="r")
axis.set(xlabel="TAXI_TIME (TaxiOut: green, TaxiIn: blue)")
# Out:
# [Text(0.5, 0, 'TAXI_TIME (TaxiOut: green, TaxiIn: blue)')]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data_flight.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
plt.title('Variable Correlation')
# Out:
# Text(0.5, 1, 'Variable Correlation')

# %%
attrition_count={}
for entry in data_flight["Month"]:
    if entry in attrition_count.keys():
        attrition_count[entry]+=1
    else:
        attrition_count[entry]=1

plt.bar(range(len(attrition_count)), attrition_count.values(), align='center')
plt.xticks(range(len(attrition_count)), list(attrition_count.keys()))

plt.show()
plt.rcParams['figure.figsize']=[10,6]

# %%
attrition_count={}
for entry in data_flight["DayofMonth"]:
    if entry in attrition_count.keys():
        attrition_count[entry]+=1
    else:
        attrition_count[entry]=1

print(attrition_count)
plt.bar(range(len(attrition_count)), attrition_count.values(), align='center')
plt.xticks(range(len(attrition_count)), list(attrition_count.keys()))
plt.show()
plt.rcParams['figure.figsize']=[20,10]

# %%
attrition_count={}
for entry in data_flight["DayOfWeek"]:
    if entry in attrition_count.keys():
        attrition_count[entry]+=1
    else:
        attrition_count[entry]=1

print(attrition_count)
plt.bar(range(len(attrition_count)), attrition_count.values(), align='center')
plt.xticks(range(len(attrition_count)), list(attrition_count.keys()))
plt.show()
plt.rcParams['figure.figsize']=[20,10]
# Out:
# {4: 1011969, 5: 1008872, 6: 841662, 7: 956127, 1: 1013409, 2: 1005991, 3: 1016994}

# %%
import datetime

# %%
data_flight['DATE'] = pd.to_datetime(data_flight[['Year','Month','DayofMonth']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-f80315269b61> in <module>
# ----> 1 data_flight['DATE'] = pd.to_datetime(data_flight[['Year','Month','DayofMonth']])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
# --> 595         result = _assemble_from_unit_mappings(arg, errors, box, tz)
#     596     elif isinstance(arg, ABCIndexClass):
#     597         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ...

# %%
data= pd.DataFrame({'year': data_flight['Year'],
                    'month': data_flight['Month'],
                    'day':data_flight['DayofMonth']})
pd.to_datetime(df) 
data_flight.append(data, ignore_index = Truem)
data_flight.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-f90824ef82fb> in <module>
#       3                     'day':data_flight['DayofMonth']})
#       4 pd.to_datetime(df)
# ----> 5 data_flight.append(data, ignore_index = Truem)
#       6 data_flight.head()
#
# NameError: name 'Truem' is not defined
